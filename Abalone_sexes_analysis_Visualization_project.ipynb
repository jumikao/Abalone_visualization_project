# %% [markdown]
# <a href="https://colab.research.google.com/github/jumikao/Abalone_visualization_project/blob/main/Abalone_sexes_analysis_Visualization_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# !git clone https://github.com/matzim95/ML-datasets
# Out:
# Cloning into 'ML-datasets'...
# remote: Enumerating objects: 194, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 194 (delta 33), reused 124 (delta 24), pack-reused 60
# Receiving objects: 100% (194/194), 35.45 MiB | 21.75 MiB/s, done.
# Resolving deltas: 100% (45/45), done.

# %%
uchowce=pd.read_csv("ML-datasets/abalone.csv", index_col="sex")
#uchowce gdzie kol 'sex' =indeks

# %% [markdown]
# PROJEKT DOTYCZY ZWIERZĘCIA - "UCHOWIEC" - "ABALONE" (SKORUPIAK)
#
# BADANIE: PORÓWNANIE UCHOWCÓW RÓŻNYCH PŁCI. CZY WYSTĘPUJĄ ZASADNICZE RÓŻNICE MIĘDZY UCHOWCAMI PŁCI MĘSKIEJ I ŻEŃSKIEJ

# %%
uchowce.head(100)
# Out:
#      length  diameter  height  whole weight  shucked weight  viscera weight  \
# sex
# M     0.455     0.365   0.095        0.5140          0.2245          0.1010
# M     0.350     0.265   0.090        0.2255          0.0995          0.0485
# F     0.530     0.420   0.135        0.6770          0.2565          0.1415
# M     0.440     0.365   0.125        0.5160          0.2155          0.1140
# I     0.330     0.255   0.080        0.2050          0.0895          0.0395
# ..      ...       ...     ...           ...             ...             ...
# M     0.665     0.535   0.195        1.6060          0.5755          0.3880
# M     0.535     0.435   0.150        0.7250          0.2690          0.1385
# M     0.470     0.375   0.130        0.5230          0.2140          0.1320
# M     0.470     0.370   0.130        0.5225          0.2010          0.1330
# F     0.475     0.375   0.125        0.5785          0.2775          0.0850
#
#      shell weight  rings
# sex
# ...

# %%
uchowce.info()
#W pliku przedstawiono 4177 pozycji.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4177 entries, M to M
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   length          4177 non-null   float64
#  1   diameter        4177 non-null   float64
#  2   height          4177 non-null   float64
#  3   whole weight    4177 non-null   float64
#  4   shucked weight  4177 non-null   float64
#  5   viscera weight  4177 non-null   float64
#  6   shell weight    4177 non-null   float64
#  7   rings           4177 non-null   int64
# dtypes: float64(7), int64(1)
# memory usage: 293.7+ KB

# %%
uchowce100=uchowce.iloc[:100,:]
#Do badania wybieram 100 pierwszych pozycji z pliku "Abalone". 
#Dla tabeli uchowce100 indeksem jest płeć osobnika.

# %%
uchowce100.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, M to F
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   length          100 non-null    float64
#  1   diameter        100 non-null    float64
#  2   height          100 non-null    float64
#  3   whole weight    100 non-null    float64
#  4   shucked weight  100 non-null    float64
#  5   viscera weight  100 non-null    float64
#  6   shell weight    100 non-null    float64
#  7   rings           100 non-null    int64
# dtypes: float64(7), int64(1)
# memory usage: 7.0+ KB

# %%
uchowce100.columns
#Następujące cechy wyróżniono dla uchowców.
# Out:
# Index(['length', 'diameter', 'height', 'whole weight', 'shucked weight',
#        'viscera weight', 'shell weight', 'rings'],
#       dtype='object')

# %%
set(uchowce100.index)
#Wśród uchowców możemy rozróżnić 3 płcie: F-female, M-male, I-Inne.
# Out:
# {'F', 'I', 'M'}

# %%
uchowce100_indeks0=uchowce=pd.read_csv("ML-datasets/abalone.csv")
#adnotacja techniczna- inny zapis tabeli dla wybranych do analizy uchowce (indeks = 0,1,2,3...)

# %%
groupby=uchowce100.groupby('sex')
F, I, M = [groupby.get_group(x) for x in groupby.groups]
#Pogrupowanie osobników wg płci i stworzenie 3 zbiorów (data frame): F-Female, M-Male, I-Inne.

# %%
F
# Out:
#      length  diameter  height  whole weight  shucked weight  viscera weight  \
# sex
# F     0.530     0.420   0.135        0.6770          0.2565          0.1415
# F     0.530     0.415   0.150        0.7775          0.2370          0.1415
# F     0.545     0.425   0.125        0.7680          0.2940          0.1495
# F     0.550     0.440   0.150        0.8945          0.3145          0.1510
# F     0.525     0.380   0.140        0.6065          0.1940          0.1475
# F     0.535     0.405   0.145        0.6845          0.2725          0.1710
# F     0.470     0.355   0.100        0.4755          0.1675          0.0805
# F     0.440     0.340   0.100        0.4510          0.1880          0.0870
# F     0.565     0.440   0.155        0.9395          0.4275          0.2140
# F     0.550     0.415   0.135        0.7635          0.3180          0.2100
# F     0.615     0.480   0.165        1.1615          0.5130          0.3010
# ...

# %%
M
# Out:
#      length  diameter  height  whole weight  shucked weight  viscera weight  \
# sex
# M     0.455     0.365   0.095        0.5140          0.2245          0.1010
# M     0.350     0.265   0.090        0.2255          0.0995          0.0485
# M     0.440     0.365   0.125        0.5160          0.2155          0.1140
# M     0.475     0.370   0.125        0.5095          0.2165          0.1125
# M     0.430     0.350   0.110        0.4060          0.1675          0.0810
# M     0.490     0.380   0.135        0.5415          0.2175          0.0950
# M     0.500     0.400   0.130        0.6645          0.2580          0.1330
# M     0.365     0.295   0.080        0.2555          0.0970          0.0430
# M     0.450     0.320   0.100        0.3810          0.1705          0.0750
# M     0.355     0.280   0.095        0.2455          0.0955          0.0620
# M     0.590     0.445   0.140        0.9310          0.3560          0.2340
# ...

# %%
plt.figure(figsize=(12,10))
sns.countplot(x=uchowce100.index, data=uchowce100)

#podpis na osi x,y
plt.xlabel("Płeć osobników", fontsize=15 )            
plt.ylabel("Liczba osobników", fontsize=15)

#tytuł
plt.title("Porównanie ilośći osobników w populacji wg płci", fontsize=20)

#WNIOSKI
#Porównanie ilośći osobników w populacji wg płci: w populacji występuje równa ilość samców i samic,
#oraz występuje ok. 4-krotnie mniejsza od ww. kategorii ilość uchowców o innej płci.
# Out:
# Text(0.5, 1.0, 'Porównanie ilośći osobników w populacji wg płci')

# %%
plt.figure(figsize=(10,8))
sns.barplot(x="sex",y="length", data=uchowce100_indeks0, hue="sex")    

plt.xlabel("Płeć osobników", fontsize=15 )            
plt.ylabel("Długość osobników", fontsize=15)
plt.title("Porównanie długości osobników w populacji wg płci", fontsize=20)

#WNIOSKI
#Samice uchowców są nieznacznie dłuższe od samców. Samice i samce są znacznie dłuższe od uchowców
#innej płci.
# Out:
# Text(0.5, 1.0, 'Porównanie długości osobników w populacji wg płci')

# %%
plt.figure(figsize=(10,8))
sns.barplot(x="sex",y="height", data=uchowce100_indeks0, hue="sex")    

plt.xlabel("Płeć osobników", fontsize=15 )            
plt.ylabel("Wysokość osobników", fontsize=15)
plt.title("Porównanie wysokości osobników w populacji wg płci", fontsize=20)

#WNIOSKI
#Samice uchowców są nieznacznie wyższe od samców. Samice i samce są znacznie wyższe od uchowców
#innej płci.
# Out:
# Text(0.5, 1.0, 'Porównanie wysokości osobników w populacji wg płci')

# %%
plt.figure(figsize=(10,8))
sns.barplot(x="sex",y="diameter", data=uchowce100_indeks0, hue="sex")    

plt.xlabel("Płeć osobników", fontsize=15 )            
plt.ylabel("Szerokość osobników", fontsize=15)
plt.title("Porównanie szerokość osobników w populacji wg płci", fontsize=20)

#WNIOSKI
#Samice uchowców są nieznacznie szersze od samców. Samice i samce są znacznie szersze od uchowców
#innej płci.
# Out:
# Text(0.5, 1.0, 'Porównanie szerokość osobników w populacji wg płci')

# %%
plt.figure(figsize=(10,8))
sns.barplot(x="sex",y="whole weight", data=uchowce100_indeks0, hue="sex")    

plt.xlabel("Płeć osobników", fontsize=15 )            
plt.ylabel("Waga osobników", fontsize=15)
plt.title("Porównanie wagi osobników w populacji wg płci", fontsize=20)

#WNIOSKI
#Samice uchowców są nieznacznie cięższe od samców. Samice i samce są znacznie cięższe od uchowców
#innej płci.
# Out:
# Text(0.5, 1.0, 'Porównanie wagi osobników w populacji wg płci')

# %%
plt.figure(figsize=(12,10))
sns.lmplot(x="length", y="diameter", data=uchowce100_indeks0, fit_reg=False, hue="sex")  

#podpis na osi x,y
plt.xlabel("Długość osobnika", fontsize=15)            
plt.ylabel("Szerokość osobnika", fontsize=15)

#tytuł
plt.title("Porównanie szerokości i długości osobnika wg płci", fontsize=20)

#WNIOSKI
#Widać niemalże równą zależność między szerokością, a długością osobnika uchowca dla samców,
#samic i osobników innej płci.
#Widać, iż samce i samice osiągają większe parametry dla szerokości i długości osobnika, niż
#uchowce innej płci.
# Out:
# Text(0.5, 1.0, 'Porównanie szerokości i długości osobnika wg płci')

# %%
plt.figure(figsize=(12,10))
sns.lmplot(x="length", y="height", data=uchowce100_indeks0, fit_reg=False, hue="sex")  

#podpis na osi x,y
plt.xlabel("Długość osobnika", fontsize=15)            
plt.ylabel("Wysokość osobnika", fontsize=15)

#tytuł
plt.title("Porównanie długości i wysokości osobnika wg płci", fontsize=20)

plt.ylim(0, 0.3)

#WNIOSKI
#Widać niemalże równą zależność między długością, a wysokością osobnika uchowca dla samców,
#samic i osobników innej płci.
#Widać, iż samce i samice osiągają większe parametry dla długości i wysokości osobnika, niż
#uchowce innej płci.
# Out:
# (0.0, 0.3)

# %%
plt.figure(figsize=(12,10))
sns.swarmplot(x="sex", y="whole weight", data=uchowce100_indeks0, hue="sex")

#podpis na osi x,y
plt.xlabel("Płeć osobnika", fontsize=15)            
plt.ylabel("Waga osobnika", fontsize=15)

#tytuł
plt.title("Porównanie wag osobników wg płci", fontsize=20)

plt.legend(loc=2, bbox_to_anchor=(1,1))

#WNIOSKI
#Waga samic i samców uchowców jest na zbliżonym poziomie, natomiast osobniki innej płci mają
#znacząco niższą wagę.
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 6.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(12,10))
sns.swarmplot(x="sex", y="shell weight", data=uchowce100_indeks0, hue="sex")

#podpis na osi x,y
plt.xlabel("Płeć osobnika", fontsize=15)            
plt.ylabel("Waga skorupy osobnika", fontsize=15)

#tytuł
plt.title("Porównanie wag skorup osobników wg płci", fontsize=20)

plt.legend(loc=2, bbox_to_anchor=(1,1))

#WNIOSKI
#Waga skorup samic i samców uchowców jest na zbliżonym poziomie, natomiast osobniki innej płci mają
#znacząco niższą wagę skorup.
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 17.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 11.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 30.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(10,8))
sns.stripplot(x="rings", y="sex", data=uchowce100_indeks0, hue="sex")

#podpis na osi x,y
plt.xlabel("Ilość pierścieni", fontsize=15)            
plt.ylabel("Płeć osobnika", fontsize=15)

#tytuł
plt.title("Porównanie ilości pierścieni osobników wg płci", fontsize=20)

plt.legend(loc=2, bbox_to_anchor=(1,1))

#WNIOSKI
#Ilość pierścieni u samic i samców uchowców jest na zbliżonym poziomie, natomiast osobniki innej płci mają
#mają znacząco niższą ilość pierścieni.

# %%
g=sns.boxplot(data=M)
plt.ylim(0, 20)
# Out:
# (0.0, 20.0)

# %%
g=sns.boxplot(data=F)
plt.ylim(0, 20)
# Out:
# (0.0, 20.0)

# %%
g=sns.boxplot(data=I)
plt.ylim(0, 20)
# Out:
# (0.0, 20.0)

# %%
df_melt=uchowce100_indeks0.melt(id_vars="sex", value_vars=["length", "diameter","height"])
df_melt.head(5000)
# Out:
#      sex  variable  value
# 0      M    length  0.455
# 1      M    length  0.350
# 2      F    length  0.530
# 3      M    length  0.440
# 4      I    length  0.330
# ...   ..       ...    ...
# 4995   I  diameter  0.250
# 4996   I  diameter  0.300
# 4997   I  diameter  0.275
# 4998   I  diameter  0.275
# 4999   I  diameter  0.275
#
# [5000 rows x 3 columns]

# %%
sns.boxplot(data=df_melt)

# %%
plt.figure(figsize=(10,8))

#liczenie korelacji między zmiennymi - count_corr
count_corr=uchowce100.corr()            

#heatmap
sns.heatmap(count_corr)

#tytuł
plt.title("Korelacja cech osobników", fontsize=20)


# Znak współczynnika korelacji informuje nas o kierunku korelacji, natomiast jego
# bezwzględna wartość o sile związku. Mamy oczywiście równość rxy = ryx. Jeśli rxy = 0,
# oznacza to zupełny brak związku korelacyjnego między badanymi zmiennymi X i Y
# (przypadek  na rysunku). Im wartość bezwzględna współczynnika korelacji jest bliższy
# jedności, tym zależność korelacyjna między zmiennymi jest silniejsza. Gdy rxy = |1|, to
# zależność korelacyjna przechodzi w zależność funkcyjną (funkcja liniowa).

# W analizie statystycznej zwykle przyjmuje się następującą skalę:
# rxy = 0 zmienne nie są skorelowane
# 0 < rxy < 0,1 korelacja nikła
# 0,1 < rxy < 0,3 korelacja słaba
# 0,3 < rxy < 0,5 korelacja przeciętna
# 0,5 < rxy < 0,7 korelacja wysoka
# 0,7 < rxy < 0,9 korelacja bardzo wysoka
# 0,9 < rxy < 1 korelacja prawie pełna.

#WNIOSKI
#Liczba pierścieni posiada bardzo wysoką korelację ze wszystkimi innymi cechami uchowców.
#Występuje wysoka korelacja pomiędzy wagą (ogólną, skorupy, wnętrzności oraz szkieletu wewnętrznego)
#, a wzrostem osobników.
#Szerokość i dlugość osobników sa nisko skorelowane ze sobą.
# Out:
# Text(0.5, 1.0, 'Korelacja cech osobników')

# %% [markdown]
# WNIOSKI OGÓLNE
#
# W większości kategorii cechy samic i samców uchowców są bardzo zbliżone (z niewielką przewagą wartości u samic), natomiast we wszystkich kategoriach cech uchowce o innej płci osiągały niższe wartości niż samce i samice.
